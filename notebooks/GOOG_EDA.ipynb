# %% [markdown]
# ### Financial Stock Analysis
# This notebook performs analysis of GOOGLE stock data, including technical indicators, financial metrics, and different kinds visualizations.

# %%
import sys
import os

# %%
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.financial_analyzer import *

# %%
# Load the data
df = load_stock_data('../data/yfinance_data/GOOG_historical_data.csv')
# Google ticker symbol 
ticker = 'GOOG'

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2004-08-19  2.490664  2.591785  2.390042  2.499133   2.496292  897427216
# 2004-08-20  2.515820  2.716817  2.503118  2.697639   2.694573  458857488
# 2004-08-23  2.758411  2.826406  2.716070  2.724787   2.721690  366857939
# 2004-08-24  2.770615  2.779581  2.579581  2.611960   2.608991  306396159
# 2004-08-25  2.614201  2.689918  2.587302  2.640104   2.637103  184645512
#
#             Dividends  Stock Splits
# Date
# 2004-08-19        0.0           0.0
# 2004-08-20        0.0           0.0
# 2004-08-23        0.0           0.0
# 2004-08-24        0.0           0.0
# 2004-08-25        0.0           0.0

# %% [markdown]
# #### Basic Statistical Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5020 entries, 2004-08-19 to 2024-07-30
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          5020 non-null   float64
#  1   High          5020 non-null   float64
#  2   Low           5020 non-null   float64
#  3   Close         5020 non-null   float64
#  4   Adj Close     5020 non-null   float64
#  5   Volume        5020 non-null   int64
#  6   Dividends     5020 non-null   float64
#  7   Stock Splits  5020 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 353.0 KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  5020.000000  5020.000000  5020.000000  5020.000000  5020.000000
# mean     45.251315    45.728793    44.800587    45.274515    45.224493
# std      43.338635    43.818298    42.918167    43.377299    43.332534
# min       2.470490     2.534002     2.390042     2.490913     2.488082
# 25%      13.034705    13.145415    12.881592    13.032090    13.017277
# 50%      26.982210    27.194902    26.791387    27.005927    26.975230
# 75%      60.215126    60.758375    59.811811    60.280252    60.211734
# max     191.750000   193.309998   190.619995   192.660004   192.660004
#
#              Volume    Dividends  Stock Splits
# count  5.020000e+03  5020.000000   5020.000000
# mean   1.157539e+08     0.000040      0.004583
# std    1.497936e+08     0.002823      0.284034
# min    1.584340e+05     0.000000      0.000000
# 25%    2.733950e+07     0.000000      0.000000
# 50%    5.585480e+07     0.000000      0.000000
# 75%    1.425333e+08     0.000000      0.000000
# max    1.650833e+09     0.200000     20.000000

# %%
df.shape
# Out:
# (5020, 8)

# %% [markdown]
# ### Technical Indicators
# Technical indicators are statistical calculations that analyze historical price data to identify potential trading signals.
# The function calculate technical indicators like: 50-day SImple Moving Average(SMA), 14-day Relative Strength Index (RSI) and Moving Average Convergence Divergence (MACD) with a fast period of 12, a slow period of 26, and a signal period of 9

# %%
#  Calculate technical indicators
df = technical_indicators(df)

# plot plot_technical_indicators
plot_technical_indicators(df, ticker)

# %% [markdown]
# ### Financial Metrics
# calculate and display some key financial metrics:average daily return, total cumulative return, average volatility, total dividends paid, number of stock splits. They give us insight into the stock's performance over time.

# %%
# Calculate financial metrics
df = financial_metrics(df)

# plot for the financial analyzer 
plot_financial_metrics(df, ticker)

# %% [markdown]
# #### stock price movements
# visualizes adjusted stock price data and a 50-day Simple Moving Average (SMA)

# %%
 #stock's price movements
plot_stock_data(df, ticker)

# %% [markdown]
# #### volume vs dividends
#  relationship between stock volume and dividend payments over time to see insights for market dynamics,
#  investor behavior, and potential trading opportunities.

# %%
plot_volume_and_dividends(df, ticker)

# %% [markdown]
# ### Other  Analysis

# %% [markdown]
# #####  Closing price over time to see long-term trends, whether the stock is generally increasing or decreasing

# %%
# plot closing price over the year 
plot_time_series_closing_price(df, ticker)

# %% [markdown]
# #####  trading volume of a stock over time.
#  helps identify periods of high or low market activity, providing insights into liquidity, investor interest, and market sentiment for the stock

# %%
plot_time_series_volume(df, ticker)

# %% [markdown]
# #####  Moving Averages
# plots for three different moving averages (30-day, 60-day, and 90-day) for a stock's closing prices to identify trends and momentum over specific time periods and it also helps detect potential reversals or confirmations of market trends.

# %%
calculate_and_plot_moving_averages(df, ticker)

# %% [markdown]
# #####  daily price change percentage for the stock

# %%
calculate_and_plot_daily_change(df, ticker)

# %% [markdown]
# #### daily price change percentage and trading volume
#  To identify whether significant price movements are associated with higher or lower trading volumes,

# %%
plot_volume_vs_price_change(df, ticker)

# %%
# Analyze the results
print("Basic Statistics:")
print(df.describe())
# Out:
# Basic Statistics:
#               Open         High          Low        Close    Adj Close  \
# count  5020.000000  5020.000000  5020.000000  5020.000000  5020.000000
# mean     45.251315    45.728793    44.800587    45.274515    45.224493
# std      43.338635    43.818298    42.918167    43.377299    43.332534
# min       2.470490     2.534002     2.390042     2.490913     2.488082
# 25%      13.034705    13.145415    12.881592    13.032090    13.017277
# 50%      26.982210    27.194902    26.791387    27.005927    26.975230
# 75%      60.215126    60.758375    59.811811    60.280252    60.211734
# max     191.750000   193.309998   190.619995   192.660004   192.660004
#
#              Volume    Dividends  Stock Splits       SMA_50          RSI  \
# count  5.020000e+03  5020.000000   5020.000000  4971.000000  5006.000000
# mean   1.157539e+08     0.000040      0.004583    44.814758    54.428017
# std    1.497936e+08     0.002823      0.284034    42.330602    12.505456
# min    1.584340e+05     0.000000      0.000000     3.164309    21.330543
# 25%    2.733950e+07     0.000000      0.000000    13.135694    45.162385
# 50%    5.585480e+07     0.000000      0.000000    27.227174    54.300169
# 75%    1.425333e+08     0.000000      0.000000    59.887655    63.520589
# max    1.650833e+09     0.200000     20.000000   180.394800    90.929422
#
#               MACD  MACD_Signal  Daily_Return  Cumulative_Return   Volatility  \
# count  4987.000000  4987.000000   5019.000000        5019.000000  5000.000000
# mean      0.250908     0.251564      0.001029          17.120076     0.017322
# std       1.089952     1.019563      0.019318          17.358805     0.008560
# min      -5.105882    -4.639486     -0.116091          -0.003289     0.002915
# 25%      -0.138539    -0.128586     -0.007854           4.216314     0.011273
# 50%       0.145691     0.149583      0.000802           9.806289     0.015179
# 75%       0.492416     0.483389      0.010138          23.122566     0.020928
# max       5.218553     4.888574      0.199915          76.178462     0.057755
#
#               MA30         MA60         MA90  Daily_Change_Pct
# count  4991.000000  4961.000000  4931.000000       5019.000000
# mean     45.004320    44.721651    44.459228          0.102853
# std      42.759942    42.121399    41.541227          1.931820
# min       2.760594     3.392173     3.734134        -11.609130
# 25%      13.136656    13.205581    13.285186         -0.785423
# 50%      27.114615    27.273931    27.578443          0.080160
# 75%      60.082692    59.606592    58.544339          1.013812
# max     183.489667   178.756667   171.767445         19.991540

# %% [markdown]
# #### correlation matrix to see how different variables relate to each other..

# %%
print("\nCorrelation Matrix:")
print(df[[ 'Open','Close','High', 'Low', 'Adj Close', 'SMA_50', 'RSI', 'MACD', 'Daily_Return', 'Cumulative_Return', 'Volatility', 'Volume', 'Dividends']].corr())
# Out:
# Correlation Matrix:
#                        Open     Close      High       Low  Adj Close  \
# Open               1.000000  0.999798  0.999915  0.999906   0.999798
# Close              0.999798  1.000000  0.999905  0.999916   1.000000
# High               0.999915  0.999905  1.000000  0.999893   0.999905
# Low                0.999906  0.999916  0.999893  1.000000   0.999916
# Adj Close          0.999798  1.000000  0.999905  0.999916   1.000000
# SMA_50             0.996406  0.996260  0.996569  0.996112   0.996258
# RSI                0.040789  0.044534  0.040922  0.044570   0.044535
# MACD               0.318603  0.319335  0.316570  0.321475   0.319360
# Daily_Return      -0.007520  0.002991 -0.002815 -0.002149   0.002988
# Cumulative_Return  0.999798  1.000000  0.999905  0.999916   1.000000
# Volatility        -0.043877 -0.043923 -0.041449 -0.046294  -0.043936
# Volume            -0.465812 -0.466021 -0.465038 -0.466803  -0.465994
# Dividends          0.042736  0.042748  0.042765  0.042622   0.042809
#
#                      SMA_50       RSI      MACD  Daily_Return  \
# Open               0.996406  0.040789  0.318603     -0.007520
# Close              0.996260  0.044534  0.319335      0.002991
# High               0.996569  0.040922  0.316570     -0.002815
# Low                0.996112  0.044570  0.321475     -0.002149
# Adj Close          0.996258  0.044535  0.319360      0.002988
# SMA_50             1.000000  0.001238  0.241042     -0.006245
# RSI                0.001238  1.000000  0.546196      0.324536
# MACD               0.241042  0.546196  1.000000      0.029373
# Daily_Return      -0.006245  0.324536  0.029373      1.000000
# Cumulative_Return  0.996258  0.044535  0.319360      0.002988
# Volatility        -0.022946 -0.167840 -0.199199      0.012313
# Volume            -0.469050  0.025365 -0.112248      0.035921
# Dividends          0.041070  0.004247  0.030256      0.002907
#
#                    Cumulative_Return  Volatility    Volume  Dividends
# Open                        0.999798   -0.043877 -0.465812   0.042736
# Close                       1.000000   -0.043923 -0.466021   0.042748
# High                        0.999905   -0.041449 -0.465038   0.042765
# Low                         0.999916   -0.046294 -0.466803   0.042622
# Adj Close                   1.000000   -0.043936 -0.465994   0.042809
# SMA_50                      0.996258   -0.022946 -0.469050   0.041070
# RSI                         0.044535   -0.167840  0.025365   0.004247
# MACD                        0.319360   -0.199199 -0.112248   0.030256
# Daily_Return                0.002988    0.012313  0.035921   0.002907
# Cumulative_Return           1.000000   -0.043936 -0.466281   0.042810
# Volatility                 -0.043936    1.000000  0.362498  -0.012735
# Volume                     -0.466281    0.362498  1.000000  -0.009295
# Dividends                   0.042810   -0.012735 -0.009295   1.000000

# %%
# Additional analysis
print("\nAverage Daily Return:", df['Daily_Return'].mean())
print("Total Cumulative Return:", df['Cumulative_Return'].iloc[-1])
print("Average Volatility:", df['Volatility'].mean())
print("Total Dividends Paid:", df['Dividends'].sum())
print("Number of Stock Splits:", df['Stock Splits'].sum())
# Out:
# Average Daily Return: 0.0010287557327918523
# Total Cumulative Return: 67.84610307205935
# Average Volatility: 0.01732236378383665
# Total Dividends Paid: 0.2
# Number of Stock Splits: 23.0047455

# %%
 #Analyze the impact of dividends and stock splits on the stock's performance 
print("\nDays with Dividends:")
print(df[df['Dividends'] > 0])

print("\nDays with Stock Splits:")
print(df[df['Stock Splits'] > 0])
# Out:
# Days with Dividends:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-06-10  176.449997  178.470001  174.380005  176.630005  176.630005
#
#               Volume  Dividends  Stock Splits   SMA_50        RSI      MACD  \
# Date
# 2024-06-10  17122200        0.2           0.0  167.365  58.184889  2.579301
#
#             MACD_Signal  Daily_Return  Cumulative_Return  Volatility  \
# Date
# 2024-06-10     3.201626      0.005007          69.756939    0.009616
#
#                   MA30     MA60        MA90  Daily_Change_Pct
# Date
# 2024-06-10  173.623667  164.401  156.880444          0.386478
#
# Days with Stock Splits:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-03-27   28.322241   28.322241   27.570307   27.846546   27.814894
# 2015-04-27   28.169500   28.297501   27.660000   27.768499   27.736937
# 2022-07-18  113.440002  114.800003  109.300003  109.910004  109.785072
#
#               Volume  Dividends  Stock Splits      SMA_50        RSI  \
# Date
# 2014-03-27    262719        0.0      2.002000   29.354640  30.190637
# 2015-04-27  47960000        0.0      1.002746   27.389567  57.929185
# 2022-07-18  33354000        0.0     20.000000  113.017831  43.877694
#
#                 MACD  MACD_Signal  Daily_Return  Cumulative_Return  \
# Date
# 2014-03-27 -0.277899    -0.010927     -0.012309          10.142482
# 2015-04-27  0.014505    -0.133192     -0.014450          10.111253
# 2022-07-18 -0.267734     0.032134     -0.025335          42.979253
#
#             Volatility        MA30        MA60        MA90  Daily_Change_Pct
# Date
# 2014-03-27    0.011103   29.814753   29.140099   28.298003         -1.230879
# 2015-04-27    0.012840   27.235907   27.243548   26.720525         -1.445023
# 2022-07-18    0.025448  113.092550  114.090984  121.167422         -2.533538

# %% [markdown]
# #### Seasonality check
#  calculates and visualizes the average monthly closing price for the stock, providing insight into how the stock performs on average during each month of the year. It helps detect seasonal patterns in stock price movements.

# %%
print("\nMonthly Average Closing Prices:")
resample_and_plot_monthly_average(df, ticker)
# Out:
# Monthly Average Closing Prices:
# Month
# 1     44.808294
# 2     45.415241
# 3     44.886074
# 4     46.454008
# 5     47.769754
# 6     47.895686
# 7     49.928518
# 8     43.873155
# 9     42.227494
# 10    42.333460
# 11    43.865610
# 12    43.865727
# Name: Close, dtype: float64
