# %% [markdown]
# ### Financial Stock Analysis
# This notebook performs analysis of AMAZON stock data, including technical indicators, financial metrics, and different kinds visualizations.

# %%
import sys
import os

# %%
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.financial_analyzer import *

# %%
# Load the data
df = load_stock_data('../data/yfinance_data/AMZN_historical_data.csv')
# Amazon ticker symbol 
ticker = 'AMZN'

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close      Volume  \
# Date
# 1997-05-15  0.121875  0.125000  0.096354  0.097917   0.097917  1443120000
# 1997-05-16  0.098438  0.098958  0.085417  0.086458   0.086458   294000000
# 1997-05-19  0.088021  0.088542  0.081250  0.085417   0.085417   122136000
# 1997-05-20  0.086458  0.087500  0.081771  0.081771   0.081771   109344000
# 1997-05-21  0.081771  0.082292  0.068750  0.071354   0.071354   377064000
#
#             Dividends  Stock Splits
# Date
# 1997-05-15        0.0           0.0
# 1997-05-16        0.0           0.0
# 1997-05-19        0.0           0.0
# 1997-05-20        0.0           0.0
# 1997-05-21        0.0           0.0

# %% [markdown]
# #### Basic Statistical Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6846 entries, 1997-05-15 to 2024-07-30
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          6846 non-null   float64
#  1   High          6846 non-null   float64
#  2   Low           6846 non-null   float64
#  3   Close         6846 non-null   float64
#  4   Adj Close     6846 non-null   float64
#  5   Volume        6846 non-null   int64
#  6   Dividends     6846 non-null   float64
#  7   Stock Splits  6846 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 481.4 KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  6846.000000  6846.000000  6846.000000  6846.000000  6846.000000
# mean     37.360464    37.801009    36.882561    37.351096    37.351096
# std      53.756955    54.366449    53.087051    53.729913    53.729913
# min       0.070313     0.072396     0.065625     0.069792     0.069792
# 25%       2.070125     2.120625     2.040156     2.076750     2.076750
# 50%       8.574500     8.666750     8.466500     8.591500     8.591500
# 75%      50.453876    50.723249    50.059875    50.426500    50.426500
# max     200.089996   201.199997   199.050003   200.000000   200.000000
#
#              Volume  Dividends  Stock Splits
# count  6.846000e+03     6846.0   6846.000000
# mean   1.380713e+08        0.0      0.003944
# std    1.382346e+08        0.0      0.246789
# min    9.744000e+06        0.0      0.000000
# 25%    6.505442e+07        0.0      0.000000
# 50%    1.020650e+08        0.0      0.000000
# 75%    1.567560e+08        0.0      0.000000
# max    2.086584e+09        0.0     20.000000

# %%
df.shape
# Out:
# (6846, 8)

# %% [markdown]
# ### Technical Indicators
# Technical indicators are statistical calculations that analyze historical price data to identify potential trading signals.
# The function calculate technical indicators like: 50-day SImple Moving Average(SMA), 14-day Relative Strength Index (RSI) and Moving Average Convergence Divergence (MACD) with a fast period of 12, a slow period of 26, and a signal period of 9

# %%
#  Calculate technical indicators
df = technical_indicators(df)

# plot plot_technical_indicators
plot_technical_indicators(df, ticker)

# %% [markdown]
# ### Financial Metrics
# calculate and display some key financial metrics:average daily return, total cumulative return, average volatility, total dividends paid, number of stock splits. They give us insight into the stock's performance over time.

# %%
# Calculate financial metrics
df = financial_metrics(df)

# plot for the financial analyzer 
plot_financial_metrics(df, ticker)

# %% [markdown]
# #### stock price movements
# visualizes adjusted stock price data and a 50-day Simple Moving Average (SMA)

# %%
 #stock's price movements
plot_stock_data(df, ticker)

# %% [markdown]
# #### volume vs dividends
#  relationship between stock volume and dividend payments over time to see insights for market dynamics,
#  investor behavior, and potential trading opportunities.

# %%
plot_volume_and_dividends(df, ticker)

# %% [markdown]
# ### Other  Analysis

# %% [markdown]
# ##### Closing price over time to see long-term trends, whether the stock is generally increasing or decreasing

# %%
# plot closing price over the year 
plot_time_series_closing_price(df, ticker)

# %% [markdown]
# #####  trading volume of a stock over time.
#  helps identify periods of high or low market activity, providing insights into liquidity, investor interest, and market sentiment for the stock

# %%
plot_time_series_volume(df, ticker)

# %% [markdown]
# #####  Moving Averages
# plots for three different moving averages (30-day, 60-day, and 90-day) for a stock's closing prices to identify trends and momentum over specific time periods and it also helps detect potential reversals or confirmations of market trends.

# %%
calculate_and_plot_moving_averages(df, ticker)

# %% [markdown]
# #####  daily price change percentage for the stock

# %%
calculate_and_plot_daily_change(df, ticker)

# %% [markdown]
# #### daily price change percentage and trading volume
#  To identify whether significant price movements are associated with higher or lower trading volumes,

# %%
plot_volume_vs_price_change(df, ticker)

# %%
# Analyze the results
print("Basic Statistics:")
print(df.describe())
# Out:
# Basic Statistics:
#               Open         High          Low        Close    Adj Close  \
# count  6846.000000  6846.000000  6846.000000  6846.000000  6846.000000
# mean     37.360464    37.801009    36.882561    37.351096    37.351096
# std      53.756955    54.366449    53.087051    53.729913    53.729913
# min       0.070313     0.072396     0.065625     0.069792     0.069792
# 25%       2.070125     2.120625     2.040156     2.076750     2.076750
# 50%       8.574500     8.666750     8.466500     8.591500     8.591500
# 75%      50.453876    50.723249    50.059875    50.426500    50.426500
# max     200.089996   201.199997   199.050003   200.000000   200.000000
#
#              Volume  Dividends  Stock Splits       SMA_50          RSI  \
# count  6.846000e+03     6846.0   6846.000000  6797.000000  6832.000000
# mean   1.380713e+08        0.0      0.003944    36.940910    53.522118
# std    1.382346e+08        0.0      0.246789    52.983975    12.083384
# min    9.744000e+06        0.0      0.000000     0.088641    17.752850
# 25%    6.505442e+07        0.0      0.000000     2.104390    44.745741
# 50%    1.020650e+08        0.0      0.000000     8.770430    53.831303
# 75%    1.567560e+08        0.0      0.000000    49.822330    62.063404
# max    2.086584e+09        0.0     20.000000   187.879400    94.214138
#
#               MACD  MACD_Signal  Daily_Return  Cumulative_Return   Volatility  \
# count  6813.000000  6813.000000   6845.000000        6845.000000  6826.000000
# mean      0.194132     0.194715      0.001716         380.512293     0.029470
# std       1.380510     1.291281      0.035429         548.749983     0.019703
# min     -12.431501   -10.695326     -0.247661          -0.287233     0.004893
# 25%      -0.056285    -0.052471     -0.013028          20.216951     0.015350
# 50%       0.034906     0.034655      0.000409          86.824381     0.023448
# 75%       0.261037     0.258675      0.014671         514.298692     0.036386
# max       8.134473     6.962658      0.344714        2041.546281     0.111800
#
#               MA30         MA60         MA90  Daily_Change_Pct
# count  6817.000000  6787.000000  6757.000000       6845.000000
# mean     37.108760    36.858350    36.612535          0.171585
# std      53.286032    52.836561    52.395685          3.542914
# min       0.076398     0.093286     0.107147        -24.766068
# 25%       2.089550     2.118067     2.140756         -1.302846
# 50%       8.656550     8.817217     8.813722          0.040920
# 75%      50.049017    49.679963    49.800533          1.467129
# max     190.664667   187.118667   184.987556         34.471362

# %% [markdown]
# #### correlation matrix to see how different variables relate to each other.

# %%
print("\nCorrelation Matrix:")
print(df[[ 'Open','Close','High', 'Low', 'Adj Close', 'SMA_50', 'RSI', 'MACD', 'Daily_Return', 'Cumulative_Return', 'Volatility', 'Volume', 'Dividends']].corr())
# Out:
# Correlation Matrix:
#                        Open     Close      High       Low  Adj Close  \
# Open               1.000000  0.999805  0.999921  0.999904   0.999805
# Close              0.999805  1.000000  0.999908  0.999914   1.000000
# High               0.999921  0.999908  1.000000  0.999885   0.999908
# Low                0.999904  0.999914  0.999885  1.000000   0.999914
# Adj Close          0.999805  1.000000  0.999908  0.999914   1.000000
# SMA_50             0.996105  0.995982  0.996236  0.995845   0.995982
# RSI                0.037795  0.040797  0.038147  0.040718   0.040797
# MACD               0.219623  0.220169  0.218062  0.221926   0.220169
# Daily_Return      -0.016130 -0.010538 -0.013561 -0.013278  -0.010538
# Cumulative_Return  0.999805  1.000000  0.999908  0.999914   1.000000
# Volatility        -0.346389 -0.346432 -0.345167 -0.347612  -0.346432
# Volume            -0.297579 -0.297628 -0.296579 -0.298666  -0.297628
# Dividends               NaN       NaN       NaN       NaN        NaN
#
#                      SMA_50       RSI      MACD  Daily_Return  \
# Open               0.996105  0.037795  0.219623     -0.016130
# Close              0.995982  0.040797  0.220169     -0.010538
# High               0.996236  0.038147  0.218062     -0.013561
# Low                0.995845  0.040718  0.221926     -0.013278
# Adj Close          0.995982  0.040797  0.220169     -0.010538
# SMA_50             1.000000 -0.005390  0.135745     -0.018316
# RSI               -0.005390  1.000000  0.450491      0.301100
# MACD               0.135745  0.450491  1.000000      0.014470
# Daily_Return      -0.018316  0.301100  0.014470      1.000000
# Cumulative_Return  0.995982  0.040797  0.220169     -0.010538
# Volatility        -0.336784 -0.102021 -0.149011      0.042546
# Volume            -0.299183  0.054742 -0.073362      0.161517
# Dividends               NaN       NaN       NaN           NaN
#
#                    Cumulative_Return  Volatility    Volume  Dividends
# Open                        0.999805   -0.346389 -0.297579        NaN
# Close                       1.000000   -0.346432 -0.297628        NaN
# High                        0.999908   -0.345167 -0.296579        NaN
# Low                         0.999914   -0.347612 -0.298666        NaN
# Adj Close                   1.000000   -0.346432 -0.297628        NaN
# SMA_50                      0.995982   -0.336784 -0.299183        NaN
# RSI                         0.040797   -0.102021  0.054742        NaN
# MACD                        0.220169   -0.149011 -0.073362        NaN
# Daily_Return               -0.010538    0.042546  0.161517        NaN
# Cumulative_Return           1.000000   -0.346432 -0.298632        NaN
# Volatility                 -0.346432    1.000000  0.484738        NaN
# Volume                     -0.298632    0.484738  1.000000        NaN
# Dividends                        NaN         NaN       NaN        NaN

# %%
# Additional analysis
print("\nAverage Daily Return:", df['Daily_Return'].mean())
print("Total Cumulative Return:", df['Cumulative_Return'].iloc[-1])
print("Average Volatility:", df['Volatility'].mean())
print("Total Dividends Paid:", df['Dividends'].sum())
print("Number of Stock Splits:", df['Stock Splits'].sum())
# Out:
# Average Daily Return: 0.0017158528338257978
# Total Cumulative Return: 1854.7554917187852
# Average Volatility: 0.029470306553465747
# Total Dividends Paid: 0.0
# Number of Stock Splits: 27.0

# %%
#Analyze the impact of dividends and stock splits on the stock's performance 
print("\nDays with Dividends:")
print(df[df['Dividends'] > 0])

print("\nDays with Stock Splits:")
print(df[df['Stock Splits'] > 0])
# Out:
# Days with Dividends:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume, Dividends, Stock Splits, SMA_50, RSI, MACD, MACD_Signal, Daily_Return, Cumulative_Return, Volatility, MA30, MA60, MA90, Daily_Change_Pct]
# Index: []
#
# Days with Stock Splits:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1998-06-02    0.363542    0.370833    0.345833    0.364063    0.364063
# 1999-01-05    2.739063    3.243750    2.662500    3.112500    3.112500
# 1999-09-02    2.875000    3.096875    2.868750    3.003125    3.003125
# 2022-06-06  125.250000  128.990005  123.809998  124.790001  124.790001
#
#                 Volume  Dividends  Stock Splits      SMA_50        RSI  \
# Date
# 1998-06-02   164028000        0.0           2.0    0.373297  48.496044
# 1999-01-05  1257464000        0.0           3.0    1.721646  77.657135
# 1999-09-02   336774000        0.0           2.0    2.831281  54.609029
# 2022-06-06   135269000        0.0          20.0  134.296410  54.703641
#
#                 MACD  MACD_Signal  Daily_Return  Cumulative_Return  \
# Date
# 1998-06-02 -0.003812    -0.002234      0.020439           2.718078
# 1999-01-05  0.368163     0.339541      0.052298          30.787126
# 1999-09-02  0.110699     0.072797      0.008924          29.670109
# 2022-06-06 -2.325815    -5.718782      0.019943        1273.446761
#
#             Volatility        MA30        MA60        MA90  Daily_Change_Pct
# Date
# 1998-06-02    0.031278    0.372044    0.367720    0.334534          2.043889
# 1999-01-05    0.060596    2.147240    1.574002    1.309055          5.229774
# 1999-09-02    0.055825    2.667552    2.819792    2.985816          0.892371
# 2022-06-06    0.034619  118.292634  137.909934  142.066395          1.994281

# %% [markdown]
# #### Seasonality check
#  calculates and visualizes the average monthly closing price for the stock, providing insight into how the stock performs on average during each month of the year. It helps detect seasonal patterns in stock price movements.

# %%
print("\nMonthly Average Closing Prices:")
resample_and_plot_monthly_average(df, ticker)
# Out:
# Monthly Average Closing Prices:
# Month
# 1     36.097200
# 2     37.455258
# 3     37.287433
# 4     39.345530
# 5     38.286953
# 6     38.412840
# 7     41.066336
# 8     36.656187
# 9     36.650123
# 10    35.241987
# 11    36.004449
# 12    35.562059
# Name: Close, dtype: float64
