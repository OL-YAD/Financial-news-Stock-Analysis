# %% [markdown]
# ### Financial Stock Analysis
# This notebook performs analysis of TESLA stock data, including technical indicators, financial metrics, and different kinds visualizations.

# %%
import sys
import os

# %%
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.financial_analyzer import *

# %%
# Load the data
df = load_stock_data('../data/yfinance_data/TSLA_historical_data.csv')
# Apple ticker symbol 
ticker = 'TSLA'

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
#
#             Dividends  Stock Splits
# Date
# 2010-06-29        0.0           0.0
# 2010-06-30        0.0           0.0
# 2010-07-01        0.0           0.0
# 2010-07-02        0.0           0.0
# 2010-07-06        0.0           0.0

# %% [markdown]
# #### Basic Statistical Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3545 entries, 2010-06-29 to 2024-07-30
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          3545 non-null   float64
#  1   High          3545 non-null   float64
#  2   Low           3545 non-null   float64
#  3   Close         3545 non-null   float64
#  4   Adj Close     3545 non-null   float64
#  5   Volume        3545 non-null   int64
#  6   Dividends     3545 non-null   float64
#  7   Stock Splits  3545 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 249.3 KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3545.000000  3545.000000  3545.000000  3545.000000  3545.000000
# mean     75.505658    77.159237    73.743492    75.487264    75.487264
# std     102.530489   104.806516   100.051787   102.456615   102.456615
# min       1.076000     1.108667     0.998667     1.053333     1.053333
# 25%      11.516667    11.861333    11.216667    11.565333    11.565333
# 50%      17.463333    17.688667    17.100000    17.459333    17.459333
# 75%     161.880005   165.333328   158.360001   161.479996   161.479996
# max     411.470001   414.496674   405.666656   409.970001   409.970001
#
#              Volume  Dividends  Stock Splits
# count  3.545000e+03     3545.0   3545.000000
# mean   9.699708e+07        0.0      0.002257
# std    7.866828e+07        0.0      0.097921
# min    1.777500e+06        0.0      0.000000
# 25%    4.770600e+07        0.0      0.000000
# 50%    8.250600e+07        0.0      0.000000
# 75%    1.228890e+08        0.0      0.000000
# max    9.140820e+08        0.0      5.000000

# %%
df.shape
# Out:
# (3545, 8)

# %% [markdown]
# ### Technical Indicators
# Technical indicators are statistical calculations that analyze historical price data to identify potential trading signals.
# The function calculate technical indicators like: 50-day SImple Moving Average(SMA), 14-day Relative Strength Index (RSI) and Moving Average Convergence Divergence (MACD) with a fast period of 12, a slow period of 26, and a signal period of 9

# %%
#  Calculate technical indicators
df = technical_indicators(df)

# plot plot_technical_indicators
plot_technical_indicators(df, ticker)

# %% [markdown]
# ### Financial Metrics
# calculate and display some key financial metrics:average daily return, total cumulative return, average volatility, total dividends paid, number of stock splits. They give us insight into the stock's performance over time.

# %%
# Calculate financial metrics
df = financial_metrics(df)

# plot for the financial analyzer 
plot_financial_metrics(df, ticker)

# %% [markdown]
# #### stock price movements
# visualizes adjusted stock price data and a 50-day Simple Moving Average (SMA)

# %%
 #stock's price movements
plot_stock_data(df, ticker)

# %% [markdown]
# #### volume vs dividends
#  relationship between stock volume and dividend payments over time to see insights for market dynamics,
#  investor behavior, and potential trading opportunities.

# %%
plot_volume_and_dividends(df, ticker)

# %% [markdown]
# ### Other  Analysis

# %% [markdown]
# #####  Closing price over time to see long-term trends, whether the stock is generally increasing or decreasing

# %%
# plot closing price over the year 
plot_time_series_closing_price(df, ticker)

# %% [markdown]
# #####  trading volume of a stock over time.
#  helps identify periods of high or low market activity, providing insights into liquidity, investor interest, and market sentiment for the stock

# %%
plot_time_series_volume(df, ticker)

# %% [markdown]
# #####  Moving Averages
# plots for three different moving averages (30-day, 60-day, and 90-day) for a stock's closing prices to identify trends and momentum over specific time periods and it also helps detect potential reversals or confirmations of market trends.

# %%
calculate_and_plot_moving_averages(df, ticker)

# %% [markdown]
# #####   daily price change percentage for the stock

# %%
calculate_and_plot_daily_change(df, ticker)

# %% [markdown]
# #### daily price change percentage and trading volume
#  To identify whether significant price movements are associated with higher or lower trading volumes,

# %%
plot_volume_vs_price_change(df, ticker)

# %%
# Analyze the results
print("Basic Statistics:")
print(df.describe())
# Out:
# Basic Statistics:
#               Open         High          Low        Close    Adj Close  \
# count  3545.000000  3545.000000  3545.000000  3545.000000  3545.000000
# mean     75.505658    77.159237    73.743492    75.487264    75.487264
# std     102.530489   104.806516   100.051787   102.456615   102.456615
# min       1.076000     1.108667     0.998667     1.053333     1.053333
# 25%      11.516667    11.861333    11.216667    11.565333    11.565333
# 50%      17.463333    17.688667    17.100000    17.459333    17.459333
# 75%     161.880005   165.333328   158.360001   161.479996   161.479996
# max     411.470001   414.496674   405.666656   409.970001   409.970001
#
#              Volume  Dividends  Stock Splits       SMA_50          RSI  \
# count  3.545000e+03     3545.0   3545.000000  3496.000000  3531.000000
# mean   9.699708e+07        0.0      0.002257    74.984347    52.886059
# std    7.866828e+07        0.0      0.097921   101.225757    13.032164
# min    1.777500e+06        0.0      0.000000     1.311467    16.564126
# 25%    4.770600e+07        0.0      0.000000    11.765550    43.789237
# 50%    8.250600e+07        0.0      0.000000    17.249560    51.792597
# 75%    1.228890e+08        0.0      0.000000   162.405300    61.684000
# max    9.140820e+08        0.0      5.000000   357.870532    94.197983
#
#               MACD  MACD_Signal  Daily_Return  Cumulative_Return   Volatility  \
# count  3512.000000  3512.000000   3544.000000        3544.000000  3525.000000
# mean      0.441561     0.429636      0.002035          46.409857     0.032968
# std       5.618614     5.264684      0.035871          64.334573     0.013247
# min     -25.271333   -22.213158     -0.210628          -0.338636     0.009862
# 25%      -0.265375    -0.251629     -0.016076           6.291125     0.023083
# 50%       0.039912     0.039004      0.001223           9.962953     0.030561
# 75%       0.663943     0.659629      0.019257         100.444620     0.039440
# max      38.067930    31.285426      0.243951         256.411000     0.100268
#
#               MA30         MA60         MA90  Daily_Change_Pct
# count  3516.000000  3486.000000  3456.000000       3544.000000
# mean     75.133373    74.926719    74.787512          0.203486
# std     101.641878   101.055532   100.636083          3.587138
# min       1.299911     1.321956     1.350104        -21.062824
# 25%      11.828539    12.272672    12.655791         -1.607620
# 50%      17.441245    17.127489    17.006418          0.122345
# 75%     164.135916   163.029499   170.424805          1.925650
# max     367.634444   356.038332   336.829480         24.395076

# %% [markdown]
# #### correlation matrix to see how different variables relate to each other.

# %%
print("\nCorrelation Matrix:")
print(df[[ 'Open','Close','High','Low', 'Adj Close', 'SMA_50', 'RSI', 'MACD', 'Daily_Return', 'Cumulative_Return', 'Volatility', 'Volume', 'Dividends']].corr())
# Out:
# Correlation Matrix:
#                        Open     Close      High       Low  Adj Close  \
# Open               1.000000  0.999219  0.999724  0.999626   0.999219
# Close              0.999219  1.000000  0.999650  0.999687   1.000000
# High               0.999724  0.999650  1.000000  0.999633   0.999650
# Low                0.999626  0.999687  0.999633  1.000000   0.999687
# Adj Close          0.999219  1.000000  0.999650  0.999687   1.000000
# SMA_50             0.981911  0.981263  0.982012  0.981173   0.981263
# RSI                0.010068  0.016841  0.012552  0.014966   0.016841
# MACD               0.174223  0.176463  0.173859  0.177334   0.176463
# Daily_Return      -0.015196  0.004470 -0.006278 -0.005315   0.004470
# Cumulative_Return  0.999219  1.000000  0.999650  0.999687   1.000000
# Volatility         0.146781  0.146558  0.149831  0.142841   0.146558
# Volume             0.105546  0.106500  0.109179  0.102287   0.106500
# Dividends               NaN       NaN       NaN       NaN        NaN
#
#                      SMA_50       RSI      MACD  Daily_Return  \
# Open               0.981911  0.010068  0.174223     -0.015196
# Close              0.981263  0.016841  0.176463      0.004470
# High               0.982012  0.012552  0.173859     -0.006278
# Low                0.981173  0.014966  0.177334     -0.005315
# Adj Close          0.981263  0.016841  0.176463      0.004470
# SMA_50             1.000000 -0.098219 -0.010220     -0.026278
# RSI               -0.098219  1.000000  0.521170      0.350671
# MACD              -0.010220  0.521170  1.000000      0.047270
# Daily_Return      -0.026278  0.350671  0.047270      1.000000
# Cumulative_Return  0.981263  0.016841  0.176463      0.004470
# Volatility         0.159379 -0.010084 -0.025922      0.057934
# Volume             0.079700  0.138714  0.105894      0.082367
# Dividends               NaN       NaN       NaN           NaN
#
#                    Cumulative_Return  Volatility    Volume  Dividends
# Open                        0.999219    0.146781  0.105546        NaN
# Close                       1.000000    0.146558  0.106500        NaN
# High                        0.999650    0.149831  0.109179        NaN
# Low                         0.999687    0.142841  0.102287        NaN
# Adj Close                   1.000000    0.146558  0.106500        NaN
# SMA_50                      0.981263    0.159379  0.079700        NaN
# RSI                         0.016841   -0.010084  0.138714        NaN
# MACD                        0.176463   -0.025922  0.105894        NaN
# Daily_Return                0.004470    0.057934  0.082367        NaN
# Cumulative_Return           1.000000    0.146558  0.107069        NaN
# Volatility                  0.146558    1.000000  0.416718        NaN
# Volume                      0.107069    0.416718  1.000000        NaN
# Dividends                        NaN         NaN       NaN        NaN

# %%
# Additional analysis
print("\nAverage Daily Return:", df['Daily_Return'].mean())
print("Total Cumulative Return:", df['Cumulative_Return'].iloc[-1])
print("Average Volatility:", df['Volatility'].mean())
print("Total Dividends Paid:", df['Dividends'].sum())
print("Number of Stock Splits:", df['Stock Splits'].sum())
# Out:
# Average Daily Return: 0.0020348584568402645
# Total Cumulative Return: 138.7781189720939
# Average Volatility: 0.032967703447985545
# Total Dividends Paid: 0.0
# Number of Stock Splits: 8.0

# %%
 #Analyze the impact of dividends and stock splits on the stock's performance 
print("\nDays with Dividends:")
print(df[df['Dividends'] > 0])

print("\nDays with Stock Splits:")
print(df[df['Stock Splits'] > 0])
# Out:
# Days with Dividends:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume, Dividends, Stock Splits, SMA_50, RSI, MACD, MACD_Signal, Daily_Return, Cumulative_Return, Volatility, MA30, MA60, MA90, Daily_Change_Pct]
# Index: []
#
# Days with Stock Splits:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-08-31  148.203339  166.713333  146.703339  166.106674  166.106674
# 2022-08-25  302.359985  302.959991  291.600006  296.070007  296.070007
#
#                Volume  Dividends  Stock Splits      SMA_50        RSI  \
# Date
# 2020-08-31  355123200        0.0           5.0  102.561600  84.396917
# 2022-08-25   53230000        0.0           3.0  264.619734  55.864367
#
#                  MACD  MACD_Signal  Daily_Return  Cumulative_Return  \
# Date
# 2020-08-31  15.262632    11.613899      0.125689         103.294668
# 2022-08-25   8.446746    10.745511     -0.003456         184.895740
#
#             Volatility        MA30       MA60        MA90  Daily_Change_Pct
# Date
# 2020-08-31    0.049622  114.067734   96.34960   82.215719         12.568905
# 2022-08-25    0.028877  285.118112  259.97039  264.433853         -0.345568

# %% [markdown]
# #### Seasonality check
#  calculates and visualizes the average monthly closing price for the stock, providing insight into how the stock performs on average during each month of the year. It helps detect seasonal patterns in stock price movements.

# %%
print("\nMonthly Average Closing Prices:")
resample_and_plot_monthly_average(df, ticker)
# Out:
# Monthly Average Closing Prices:
# Month
# 1     77.693880
# 2     79.115559
# 3     75.223989
# 4     75.462088
# 5     69.209828
# 6     74.050392
# 7     78.893280
# 8     73.073547
# 9     76.491644
# 10    71.549848
# 11    77.551572
# 12    78.165063
# Name: Close, dtype: float64
