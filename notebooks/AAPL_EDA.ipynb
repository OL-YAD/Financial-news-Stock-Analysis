# %% [markdown]
# ### Financial Stock Analysis
# This notebook performs analysis of APPLE stock data, including technical indicators, financial metrics, and different kinds visualizations.

# %%
import sys
import os

# %%
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.financial_analyzer import *

# %%
# Load the data
df = load_stock_data('../data/yfinance_data/AAPL_historical_data.csv')
# Apple ticker symbol 
ticker = 'AAPL'

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.098943  469033600
# 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.093781  175884800
# 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.086898  105728000
# 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089049   86441600
# 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.091630   73449600
#
#             Dividends  Stock Splits
# Date
# 1980-12-12        0.0           0.0
# 1980-12-15        0.0           0.0
# 1980-12-16        0.0           0.0
# 1980-12-17        0.0           0.0
# 1980-12-18        0.0           0.0

# %% [markdown]
# #### Basic Statistical Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10998 entries, 1980-12-12 to 2024-07-30
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          10998 non-null  float64
#  1   High          10998 non-null  float64
#  2   Low           10998 non-null  float64
#  3   Close         10998 non-null  float64
#  4   Adj Close     10998 non-null  float64
#  5   Volume        10998 non-null  int64
#  6   Dividends     10998 non-null  float64
#  7   Stock Splits  10998 non-null  float64
# dtypes: float64(7), int64(1)
# memory usage: 773.3 KB

# %%
df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  10998.000000  10998.000000  10998.000000  10998.000000  10998.000000
# mean      22.299160     22.539055     22.068367     22.312754     21.494496
# std       46.003685     46.496031     45.540929     46.037660     45.561916
# min        0.049665      0.049665      0.049107      0.049107      0.037857
# 25%        0.299107      0.303710      0.290179      0.298549      0.241840
# 50%        0.531250      0.537946      0.522321      0.531250      0.432079
# 75%       20.204196     20.389554     19.998036     20.196160     17.253029
# max      236.479996    237.229996    233.089996    234.820007    234.548523
#
#              Volume     Dividends  Stock Splits
# count  1.099800e+04  10998.000000  10998.000000
# mean   3.180806e+08      0.000752      0.001546
# std    3.354523e+08      0.011753      0.083663
# min    0.000000e+00      0.000000      0.000000
# 25%    1.132545e+08      0.000000      0.000000
# 50%    2.057412e+08      0.000000      0.000000
# 75%    3.985275e+08      0.000000      0.000000
# max    7.421641e+09      0.250000      7.000000

# %%
df.shape
# Out:
# (10998, 8)

# %% [markdown]
# ### Technical Indicators
# Technical indicators are statistical calculations that analyze historical price data to identify potential trading signals.
# The function calculate technical indicators like: 50-day SImple Moving Average(SMA), 14-day Relative Strength Index (RSI) and Moving Average Convergence Divergence (MACD) with a fast period of 12, a slow period of 26, and a signal period of 9

# %%
#  Calculate technical indicators
df = technical_indicators(df)

# plot plot_technical_indicators
plot_technical_indicators(df, ticker)

# %% [markdown]
# ### Financial Metrics
# calculate and display some key financial metrics:average daily return, total cumulative return, average volatility, total dividends paid, number of stock splits. They give us insight into the stock's performance over time.

# %%
# Calculate financial metrics
df = financial_metrics(df)

# plot for the financial analyzer 
plot_financial_metrics(df, ticker)

# %% [markdown]
# #### stock price movements
# visualizes adjusted stock price data and a 50-day Simple Moving Average (SMA)

# %%
 #stock's price movements
plot_stock_data(df, ticker)

# %% [markdown]
# #### volume vs dividends
#  relationship between stock volume and dividend payments over time to see insights for market dynamics,
#  investor behavior, and potential trading opportunities.

# %%
plot_volume_and_dividends(df, ticker)

# %% [markdown]
# ### Other  Analysis

# %% [markdown]
# #####  Closing price over time to see long-term trends, whether the stock is generally increasing or decreasing

# %%
# plot closing price over the year 
plot_time_series_closing_price(df, ticker)

# %% [markdown]
# #####  trading volume of a stock over time.
#  helps identify periods of high or low market activity, providing insights into liquidity, investor interest, and market sentiment for the stock

# %%
plot_time_series_volume(df, ticker)

# %% [markdown]
# ##### Moving Averages
# plots for three different moving averages (30-day, 60-day, and 90-day) for a stock's closing prices to identify trends and momentum over specific time periods and it also helps detect potential reversals or confirmations of market trends.

# %%
calculate_and_plot_moving_averages(df, ticker)

# %% [markdown]
# #####   daily price change percentage for the stock

# %%
calculate_and_plot_daily_change(df, ticker)

# %% [markdown]
# #### daily price change percentage and trading volume
#  To identify whether significant price movements are associated with higher or lower trading volumes,

# %%
plot_volume_vs_price_change(df, ticker)

# %%
# Analyze the results
print("Basic Statistics:")
print(df.describe())
# Out:
# Basic Statistics:
#                Open          High           Low         Close     Adj Close  \
# count  10998.000000  10998.000000  10998.000000  10998.000000  10998.000000
# mean      22.299160     22.539055     22.068367     22.312754     21.494496
# std       46.003685     46.496031     45.540929     46.037660     45.561916
# min        0.049665      0.049665      0.049107      0.049107      0.037857
# 25%        0.299107      0.303710      0.290179      0.298549      0.241840
# 50%        0.531250      0.537946      0.522321      0.531250      0.432079
# 75%       20.204196     20.389554     19.998036     20.196160     17.253029
# max      236.479996    237.229996    233.089996    234.820007    234.548523
#
#              Volume     Dividends  Stock Splits        SMA_50           RSI  \
# count  1.099800e+04  10998.000000  10998.000000  10949.000000  10984.000000
# mean   3.180806e+08      0.000752      0.001546     21.923676     53.119636
# std    3.354523e+08      0.011753      0.083663     45.110257     13.040051
# min    0.000000e+00      0.000000      0.000000      0.057947     15.346105
# 25%    1.132545e+08      0.000000      0.000000      0.305960     43.465694
# 50%    2.057412e+08      0.000000      0.000000      0.527433     52.980476
# 75%    3.985275e+08      0.000000      0.000000     20.071600     62.755369
# max    7.421641e+09      0.250000      7.000000    210.858600     91.502574
#
#                MACD   MACD_Signal  Daily_Return  Cumulative_Return  \
# count  10965.000000  10965.000000  10997.000000       10997.000000
# mean       0.139020      0.137452      0.001096         216.260386
# std        1.013181      0.955654      0.027892         460.501809
# min       -6.673117     -5.815683     -0.518692          -0.617392
# 25%       -0.007107     -0.006533     -0.012674           1.446467
# 50%        0.003685      0.003666      0.000000           3.366936
# 75%        0.065976      0.063689      0.014451         173.375382
# max        8.948060      8.310411      0.332281        2369.536620
#
#          Volatility          MA30          MA60          MA90  \
# count  10978.000000  10969.000000  10939.000000  10909.000000
# mean       0.024892     22.076693     21.851735     21.651906
# std        0.012550     45.466244     44.950833     44.537847
# min        0.004558      0.056920      0.058687      0.061682
# 25%        0.016392      0.301339      0.307589      0.308048
# 50%        0.022576      0.529427      0.525446      0.518576
# 75%        0.030541     20.092369     20.032902     19.761183
# max        0.128855    220.746667    206.567500    194.407555
#
#        Daily_Change_Pct
# count      10997.000000
# mean           0.107255
# std            2.789465
# min          -51.869199
# 25%           -1.271047
# 50%            0.000000
# 75%            1.445077
# max           33.228046

# %% [markdown]
# #### correlation matrix to see how different variables relate to each other.

# %%
print("\nCorrelation Matrix:")
print(df[[ 'Open','Close','High','Low', 'Adj Close', 'SMA_50', 'RSI', 'MACD', 'Daily_Return', 'Cumulative_Return', 'Volatility', 'Volume', 'Dividends']].corr())
# Out:
# Correlation Matrix:
#                        Open     Close      High       Low  Adj Close  \
# Open               1.000000  0.999873  0.999945  0.999941   0.999667
# Close              0.999873  1.000000  0.999941  0.999942   0.999796
# High               0.999945  0.999941  1.000000  0.999925   0.999734
# Low                0.999941  0.999942  0.999925  1.000000   0.999743
# Adj Close          0.999667  0.999796  0.999734  0.999743   1.000000
# SMA_50             0.997161  0.997106  0.997232  0.997052   0.996928
# RSI                0.079766  0.081486  0.079887  0.081348   0.078817
# MACD               0.318366  0.318518  0.317388  0.319522   0.318128
# Daily_Return      -0.000755  0.002927  0.000812  0.001052   0.002814
# Cumulative_Return  0.999667  0.999796  0.999734  0.999743   1.000000
# Volatility        -0.308987 -0.308981 -0.308171 -0.309826  -0.301460
# Volume            -0.254604 -0.254733 -0.254235 -0.255200  -0.256273
# Dividends          0.094703  0.094528  0.094312  0.094550   0.093855
#
#                      SMA_50       RSI      MACD  Daily_Return  \
# Open               0.997161  0.079766  0.318366     -0.000755
# Close              0.997106  0.081486  0.318518      0.002927
# High               0.997232  0.079887  0.317388      0.000812
# Low                0.997052  0.081348  0.319522      0.001052
# Adj Close          0.996928  0.078817  0.318128      0.002814
# SMA_50             1.000000  0.050642  0.248099     -0.002875
# RSI                0.050642  1.000000  0.374162      0.319369
# MACD               0.248099  0.374162  1.000000      0.019787
# Daily_Return      -0.002875  0.319369  0.019787      1.000000
# Cumulative_Return  0.996928  0.078817  0.318128      0.002814
# Volatility        -0.301466 -0.216212 -0.177248     -0.011735
# Volume            -0.256010  0.030366 -0.083805      0.000620
# Dividends          0.093151  0.014035  0.046983     -0.003363
#
#                    Cumulative_Return  Volatility    Volume  Dividends
# Open                        0.999667   -0.308987 -0.254604   0.094703
# Close                       0.999796   -0.308981 -0.254733   0.094528
# High                        0.999734   -0.308171 -0.254235   0.094312
# Low                         0.999743   -0.309826 -0.255200   0.094550
# Adj Close                   1.000000   -0.301460 -0.256273   0.093855
# SMA_50                      0.996928   -0.301466 -0.256010   0.093151
# RSI                         0.078817   -0.216212  0.030366   0.014035
# MACD                        0.318128   -0.177248 -0.083805   0.046983
# Daily_Return                0.002814   -0.011735  0.000620  -0.003363
# Cumulative_Return           1.000000   -0.301460 -0.256259   0.093853
# Volatility                 -0.301460    1.000000  0.234871  -0.035768
# Volume                     -0.256259    0.234871  1.000000  -0.034727
# Dividends                   0.093853   -0.035768 -0.034727   1.000000

# %%
# Additional analysis
print("\nAverage Daily Return:", df['Daily_Return'].mean())
print("Total Cumulative Return:", df['Cumulative_Return'].iloc[-1])
print("Average Volatility:", df['Volatility'].mean())
print("Total Dividends Paid:", df['Dividends'].sum())
print("Number of Stock Splits:", df['Stock Splits'].sum())
# Out:
# Average Daily Return: 0.0010960408314183133
# Total Cumulative Return: 2207.812751027257
# Average Volatility: 0.02489237996552221
# Total Dividends Paid: 8.273564
# Number of Stock Splits: 17.0

# %%
 #Analyze the impact of dividends and stock splits on the stock's performance 
print("\nDays with Dividends:")
print(df[df['Dividends'] > 0])

print("\nDays with Stock Splits:")
print(df[df['Stock Splits'] > 0])
# Out:
# Days with Dividends:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1987-05-11    0.343750    0.354911    0.342634    0.343750    0.265399
# 1987-08-10    0.430804    0.430804    0.408482    0.430804    0.333041
# 1987-11-17    0.328125    0.330357    0.312500    0.312500    0.242111
# 1988-02-12    0.362723    0.370536    0.361607    0.366071    0.284175
# 1988-05-16    0.361607    0.369420    0.357143    0.368304    0.286474
# ...                ...         ...         ...         ...         ...
# 2023-05-12  173.619995  174.059998  171.000000  172.570007  171.459915
# 2023-08-11  177.320007  178.619995  176.550003  177.789993  176.884857
# 2023-11-10  183.970001  186.570007  183.529999  186.399994  185.695343
# 2024-02-09  188.649994  189.990005  188.000000  188.850006  188.376160
# 2024-05-10  184.899994  185.089996  182.130005  183.050003  182.838364
#
#                Volume  Dividends  Stock Splits      SMA_50        RSI  \
# Date
# 1987-05-11  197276800   0.000536           0.0    0.315112  57.024341
# 1987-08-10   77996800   0.000536           0.0    0.366964  71.837371
# 1987-11-17  268800000   0.000714           0.0    0.413817  39.612455
# 1988-02-12  137760000   0.000714           0.0    0.357388  52.172654
# 1988-05-16   74760000   0.000714           0.0    0.373728  51.847996
# ...               ...        ...           ...         ...        ...
# 2023-05-12   45497800   0.240000           0.0  162.378600  62.258794
# 2023-08-11   51988100   0.240000           0.0  187.442600  29.613073
# 2023-11-10   66133400   0.240000           0.0  176.474001  69.003591
# 2024-02-09   45155200   0.240000           0.0  190.479400  49.682095
# 2024-05-10   50759500   0.250000           0.0  172.508200  63.623300
#
#                 MACD  MACD_Signal  Daily_Return  Cumulative_Return  \
# Date
# 1987-05-11  0.012737     0.013345     -0.023835           1.682341
# 1987-08-10  0.011920     0.006637      0.038976           2.365985
# 1987-11-17 -0.022835    -0.027545     -0.045542           1.446970
# 1988-02-12 -0.001144    -0.001087      0.011221           1.872100
# 1988-05-16 -0.001728    -0.001716      0.020535           1.895336
# ...              ...          ...           ...                ...
# 2023-05-12  3.100687     2.897446     -0.005418        1731.912246
# 2023-08-11 -2.676573    -0.511711      0.000337        1786.741087
# 2023-11-10  1.858073     0.281701      0.023220        1875.786966
# 2024-02-09 -0.251576    -0.186991      0.004094        1902.881462
# 2024-05-10  3.094140     1.415880     -0.006890        1846.912027
#
#             Volatility        MA30        MA60        MA90  Daily_Change_Pct
# Date
# 1987-05-11    0.021471    0.327288    0.311142    0.282732         -2.531768
# 1987-08-10    0.029286    0.373251    0.362863    0.352964          3.763437
# 1987-11-17    0.088597    0.364286    0.421949    0.416245         -4.761905
# 1988-02-12    0.027205    0.368824    0.349870    0.354675          0.923016
# 1988-05-16    0.014254    0.363914    0.376339    0.372743          1.852019
# ...                ...         ...         ...         ...               ...
# 2023-05-12    0.013955  167.028667  160.087333  154.100666         -0.679132
# 2023-08-11    0.013743  189.871667  185.260000  179.328112         -0.101145
# 2023-11-10    0.012736  176.121668  177.120001  180.680667          2.187375
# 2024-02-09    0.012437  188.152999  190.373000  185.745334          0.281435
# 2024-05-10    0.018602  172.382667  174.138500  178.638777         -0.823538
#
# [83 rows x 19 columns]
#
# Days with Stock Splits:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1987-06-16    0.370536    0.372768    0.339286    0.370536    0.286080
# 2000-06-21    0.901786    1.016741    0.898438    0.993304    0.838821
# 2005-02-28    1.595714    1.612143    1.570000    1.602143    1.352970
# 2014-06-09   23.174999   23.469999   22.937500   23.424999   20.696278
# 2020-08-31  127.580002  131.000000  126.000000  129.039993  126.103653
#
#                Volume  Dividends  Stock Splits      SMA_50        RSI  \
# Date
# 1987-06-16  342720000        0.0           2.0    0.339777  67.929116
# 2000-06-21  490000000        0.0           2.0    0.929590  63.755318
# 2005-02-28  651610400        0.0           2.0    1.315079  71.829351
# 2014-06-09  301660000        0.0           7.0   20.687929  80.201806
# 2020-08-31  225702700        0.0           4.0  103.967600  78.257989
#
#                 MACD  MACD_Signal  Daily_Return  Cumulative_Return  \
# Date
# 1987-06-16  0.005032     0.004167      0.057327           1.891358
# 2000-06-21 -0.004514    -0.027769      0.098766           7.477797
# 2005-02-28  0.083443     0.081275      0.008203          12.674208
# 2014-06-09  0.703343     0.645291      0.016001         208.173281
# 2020-08-31  7.008900     6.561196      0.033912        1273.505264
#
#             Volatility        MA30        MA60       MA90  Daily_Change_Pct
# Date
# 1987-06-16    0.020806    0.348196    0.332998   0.317442          5.732699
# 2000-06-21    0.038401    0.846136    0.969534   1.011189          9.876577
# 2005-02-28    0.023305    1.417363    1.287696   1.189373          0.820336
# 2014-06-09    0.008674   21.789821   20.416774  19.877937          1.600138
# 2020-08-31    0.020104  110.952667  101.027583  93.046417          3.391215

# %% [markdown]
# ### Seasonality check
#  calculates and visualizes the average monthly closing price for the stock, providing insight into how the stock performs on average during each month of the year. It helps detect seasonal patterns in stock price movements.

# %%
print("\nMonthly Average Closing Prices:")
resample_and_plot_monthly_average(df, ticker)
# Out:
# Monthly Average Closing Prices:
# Month
# 1     21.511662
# 2     22.417679
# 3     21.950462
# 4     22.411277
# 5     23.009542
# 6     23.159714
# 7     24.882621
# 8     21.789419
# 9     21.524795
# 10    20.952593
# 11    22.049005
# 12    22.069498
# Name: Close, dtype: float64
