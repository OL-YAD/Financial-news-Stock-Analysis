# %% [markdown]
# ### Financial Stock Analysis
# This notebook performs analysis of MICROSOFT stock data, including technical indicators, financial metrics, and different kinds visualizations.

# %%
import sys
import os

# %%
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.financial_analyzer import *

# %%
# Load the data
df = load_stock_data('../data/yfinance_data/MSFT_historical_data.csv')
# Apple ticker symbol 
ticker = 'MSFT'

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close      Volume  \
# Date
# 1986-03-13  0.088542  0.101563  0.088542  0.097222   0.059946  1031788800
# 1986-03-14  0.097222  0.102431  0.097222  0.100694   0.062087   308160000
# 1986-03-17  0.100694  0.103299  0.100694  0.102431   0.063158   133171200
# 1986-03-18  0.102431  0.103299  0.098958  0.099826   0.061552    67766400
# 1986-03-19  0.099826  0.100694  0.097222  0.098090   0.060482    47894400
#
#             Dividends  Stock Splits
# Date
# 1986-03-13        0.0           0.0
# 1986-03-14        0.0           0.0
# 1986-03-17        0.0           0.0
# 1986-03-18        0.0           0.0
# 1986-03-19        0.0           0.0

# %% [markdown]
# #### Basic Statistical Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9672 entries, 1986-03-13 to 2024-07-30
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          9672 non-null   float64
#  1   High          9672 non-null   float64
#  2   Low           9672 non-null   float64
#  3   Close         9672 non-null   float64
#  4   Adj Close     9672 non-null   float64
#  5   Volume        9672 non-null   int64
#  6   Dividends     9672 non-null   float64
#  7   Stock Splits  9672 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 680.1 KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  9672.000000  9672.000000  9672.000000  9672.000000  9672.000000
# mean     58.402199    59.003071    57.784759    58.417683    52.719365
# std      90.122302    90.958645    89.232546    90.146786    90.066461
# min       0.088542     0.092014     0.088542     0.090278     0.055665
# 25%       5.695313     5.770508     5.617188     5.695313     3.511695
# 50%      27.304999    27.600000    27.085000    27.341875    19.145540
# 75%      46.687500    47.099998    46.138672    46.657187    38.339042
# max     467.000000   468.350006   464.459991   467.559998   466.718781
#
#              Volume    Dividends  Stock Splits
# count  9.672000e+03  9672.000000   9672.000000
# mean   5.677678e+07     0.002982      0.001758
# std    3.814123e+07     0.046524      0.057944
# min    2.304000e+06     0.000000      0.000000
# 25%    3.206982e+07     0.000000      0.000000
# 50%    4.990225e+07     0.000000      0.000000
# 75%    7.071788e+07     0.000000      0.000000
# max    1.031789e+09     3.080000      2.000000

# %%
df.shape
# Out:
# (9672, 8)

# %% [markdown]
# ### Technical Indicators
# Technical indicators are statistical calculations that analyze historical price data to identify potential trading signals.
# The function calculate technical indicators like: 50-day SImple Moving Average(SMA), 14-day Relative Strength Index (RSI) and Moving Average Convergence Divergence (MACD) with a fast period of 12, a slow period of 26, and a signal period of 9

# %%
#  Calculate technical indicators
df = technical_indicators(df)

# plot plot_technical_indicators
plot_technical_indicators(df, ticker)

# %% [markdown]
# ### Financial Metrics
# calculate and display some key financial metrics:average daily return, total cumulative return, average volatility, total dividends paid, number of stock splits. They give us insight into the stock's performance over time.

# %%
# Calculate financial metrics
df = financial_metrics(df)

# plot for the financial analyzer 
plot_financial_metrics(df, ticker)

# %% [markdown]
# #### stock price movements
# visualizes adjusted stock price data and a 50-day Simple Moving Average (SMA)

# %%
 #stock's price movements
plot_stock_data(df, ticker)

# %% [markdown]
# #### volume vs dividends
#  relationship between stock volume and dividend payments over time to see insights for market dynamics,
#  investor behavior, and potential trading opportunities.

# %%
plot_volume_and_dividends(df, ticker)

# %% [markdown]
# ### Other  Analysis

# %% [markdown]
# ##### Closing price over time to see long-term trends, whether the stock is generally increasing or decreasing

# %%
# plot closing price over the year 
plot_time_series_closing_price(df, ticker)

# %% [markdown]
# #####  trading volume of a stock over time.
#  helps identify periods of high or low market activity, providing insights into liquidity, investor interest, and market sentiment for the stock

# %%
plot_time_series_volume(df, ticker)

# %% [markdown]
# #####  Moving Averages
# plots for three different moving averages (30-day, 60-day, and 90-day) for a stock's closing prices to identify trends and momentum over specific time periods and it also helps detect potential reversals or confirmations of market trends.

# %%
calculate_and_plot_moving_averages(df, ticker)

# %% [markdown]
# #####  daily price change percentage for the stock

# %%
calculate_and_plot_daily_change(df, ticker)

# %% [markdown]
# #### daily price change percentage and trading volume
#  To identify whether significant price movements are associated with higher or lower trading volumes,

# %%
plot_volume_vs_price_change(df, ticker)

# %%
# Analyze the results
print("Basic Statistics:")
print(df.describe())
# Out:
# Basic Statistics:
#               Open         High          Low        Close    Adj Close  \
# count  9672.000000  9672.000000  9672.000000  9672.000000  9672.000000
# mean     58.402199    59.003071    57.784759    58.417683    52.719365
# std      90.122302    90.958645    89.232546    90.146786    90.066461
# min       0.088542     0.092014     0.088542     0.090278     0.055665
# 25%       5.695313     5.770508     5.617188     5.695313     3.511695
# 50%      27.304999    27.600000    27.085000    27.341875    19.145540
# 75%      46.687500    47.099998    46.138672    46.657187    38.339042
# max     467.000000   468.350006   464.459991   467.559998   466.718781
#
#              Volume    Dividends  Stock Splits       SMA_50          RSI  \
# count  9.672000e+03  9672.000000   9672.000000  9623.000000  9658.000000
# mean   5.677678e+07     0.002982      0.001758    57.587227    53.759398
# std    3.814123e+07     0.046524      0.057944    88.100794    11.699700
# min    2.304000e+06     0.000000      0.000000     0.101233    16.909075
# 25%    3.206982e+07     0.000000      0.000000     5.776934    45.555235
# 50%    4.990225e+07     0.000000      0.000000    27.294600    53.769447
# 75%    7.071788e+07     0.000000      0.000000    45.949800    62.051251
# max    1.031789e+09     3.080000      2.000000   439.183400    89.185911
#
#               MACD  MACD_Signal  Daily_Return  Cumulative_Return   Volatility  \
# count  9639.000000  9639.000000   9671.000000        9671.000000  9652.000000
# mean      0.322168     0.322697      0.001140         878.531525     0.018824
# std       1.718194     1.610138      0.021103        1502.499241     0.009755
# min      -9.487692    -8.149166     -0.301159          -0.071424     0.003487
# 25%      -0.085663    -0.067714     -0.009136          57.580508     0.012283
# 50%       0.036066     0.038131      0.000372         318.377275     0.016987
# 75%       0.439420     0.433217      0.011259         638.697336     0.023208
# max      11.527259    10.855845      0.195652        7784.592393     0.108279
#
#               MA30         MA60         MA90  Daily_Change_Pct
# count  9643.000000  9613.000000  9583.000000       9671.000000
# mean     57.927263    57.421972    56.940427          0.109062
# std      88.941174    87.698777    86.541534          2.112618
# min       0.098249     0.101324     0.103776        -30.115893
# 25%       5.787435     5.780599     5.784462         -0.920679
# 50%      27.298667    27.262250    27.264889          0.034567
# 75%      46.088932    45.916167    45.838559          1.123176
# max     449.481666   435.011000   428.136888         19.565217

# %% [markdown]
# #### correlation matrix to see how different variables relate to each other.

# %%
print("\nCorrelation Matrix:")
print(df[[ 'Open','Close','High','Low', 'Adj Close', 'SMA_50', 'RSI', 'MACD', 'Daily_Return', 'Cumulative_Return', 'Volatility', 'Volume', 'Dividends']].corr())
# Out:
# Correlation Matrix:
#                        Open     Close      High       Low  Adj Close  \
# Open               1.000000  0.999871  0.999946  0.999939   0.998835
# Close              0.999871  1.000000  0.999936  0.999944   0.998963
# High               0.999946  0.999936  1.000000  0.999923   0.998865
# Low                0.999939  0.999944  0.999923  1.000000   0.998940
# Adj Close          0.998835  0.998963  0.998865  0.998940   1.000000
# SMA_50             0.998092  0.997997  0.998206  0.997916   0.996941
# RSI                0.063582  0.066154  0.063604  0.065940   0.069402
# MACD               0.392161  0.392936  0.390383  0.394507   0.393030
# Daily_Return      -0.006887 -0.000353 -0.004000 -0.003697   0.000159
# Cumulative_Return  0.998836  0.998963  0.998865  0.998940   1.000000
# Volatility        -0.158602 -0.158565 -0.156869 -0.160255  -0.157056
# Volume            -0.345265 -0.345425 -0.344280 -0.346409  -0.345273
# Dividends          0.062717  0.062683  0.062537  0.062873   0.062650
#
#                      SMA_50       RSI      MACD  Daily_Return  \
# Open               0.998092  0.063582  0.392161     -0.006887
# Close              0.997997  0.066154  0.392936     -0.000353
# High               0.998206  0.063604  0.390383     -0.004000
# Low                0.997916  0.065940  0.394507     -0.003697
# Adj Close          0.996941  0.069402  0.393030      0.000159
# SMA_50             1.000000  0.035421  0.336873     -0.008081
# RSI                0.035421  1.000000  0.442133      0.322001
# MACD               0.336873  0.442133  1.000000      0.017680
# Daily_Return      -0.008081  0.322001  0.017680      1.000000
# Cumulative_Return  0.996941  0.069402  0.393030      0.000159
# Volatility        -0.148121 -0.148263 -0.199508      0.008995
# Volume            -0.356573 -0.118512 -0.181535     -0.005656
# Dividends          0.061519 -0.001163  0.044430      0.002147
#
#                    Cumulative_Return  Volatility    Volume  Dividends
# Open                        0.998836   -0.158602 -0.345265   0.062717
# Close                       0.998963   -0.158565 -0.345425   0.062683
# High                        0.998865   -0.156869 -0.344280   0.062537
# Low                         0.998940   -0.160255 -0.346409   0.062873
# Adj Close                   1.000000   -0.157056 -0.345273   0.062650
# SMA_50                      0.996941   -0.148121 -0.356573   0.061519
# RSI                         0.069402   -0.148263 -0.118512  -0.001163
# MACD                        0.393030   -0.199508 -0.181535   0.044430
# Daily_Return                0.000159    0.008995 -0.005656   0.002147
# Cumulative_Return           1.000000   -0.157056 -0.355972   0.062647
# Volatility                 -0.157056    1.000000  0.354844  -0.014237
# Volume                     -0.355972    0.354844  1.000000  -0.026550
# Dividends                   0.062647   -0.014237 -0.026550   1.000000

# %%
# Additional analysis
print("\nAverage Daily Return:", df['Daily_Return'].mean())
print("Total Cumulative Return:", df['Cumulative_Return'].iloc[-1])
print("Average Volatility:", df['Volatility'].mean())
print("Total Dividends Paid:", df['Dividends'].sum())
print("Number of Stock Splits:", df['Stock Splits'].sum())
# Out:
# Average Daily Return: 0.0011399717098234446
# Total Cumulative Return: 7041.268192201346
# Average Volatility: 0.018823687541458328
# Total Dividends Paid: 28.840000000000003
# Number of Stock Splits: 17.0

# %%
 #Analyze the impact of dividends and stock splits on the stock's performance 
print("\nDays with Dividends:")
print(df[df['Dividends'] > 0])

print("\nDays with Stock Splits:")
print(df[df['Stock Splits'] > 0])
# Out:
# Days with Dividends:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2003-02-19   24.820000   24.879999   24.170000   24.530001   15.173683
# 2003-10-15   29.200001   29.260000   28.700001   29.070000   18.082903
# 2004-08-23   27.270000   27.330000   27.120001   27.240000   16.994541
# 2004-11-15   27.340000   27.500000   27.200001   27.389999   19.045403
# 2005-02-15   26.000000   26.080000   25.860001   25.930000   18.085840
# ...                ...         ...         ...         ...         ...
# 2023-05-17  312.290009  314.429993  310.739990  314.000000  311.002197
# 2023-08-16  320.799988  324.420013  319.799988  320.399994  318.012970
# 2023-11-15  371.279999  373.130005  367.109985  369.670013  367.660614
# 2024-02-14  408.070007  409.839996  404.570007  409.489990  408.017303
# 2024-05-15  417.899994  423.809998  417.269989  423.079987  422.318787
#
#                Volume  Dividends  Stock Splits      SMA_50        RSI  \
# Date
# 2003-02-19   46902700       0.08           0.0   25.914100  47.947064
# 2003-10-15   57242100       0.16           0.0   27.703000  56.155013
# 2004-08-23   39572200       0.08           0.0   27.925600  44.930067
# 2004-11-15  104468000       3.08           0.0   28.041600  38.207070
# 2005-02-15   76551600       0.08           0.0   26.566200  39.486856
# ...               ...        ...           ...         ...        ...
# 2023-05-17   24315000       0.68           0.0  287.384800  67.640788
# 2023-08-16   20698900       0.68           0.0  335.294398  38.882367
# 2023-11-15   26860100       0.75           0.0  334.538203  71.719334
# 2024-02-14   20401200       0.75           0.0  387.228399  57.681095
# 2024-05-15   22239500       0.75           0.0  414.156000  60.450623
#
#                  MACD  MACD_Signal  Daily_Return  Cumulative_Return  \
# Date
# 2003-02-19  -0.589898    -0.776082 -1.406749e-02         252.120545
# 2003-10-15   0.277381     0.337969  1.928510e-02         300.650838
# 2004-08-23  -0.225840    -0.184414  4.425203e-03         282.495278
# 2004-11-15   0.331939     0.342590  1.859400e-02         316.706823
# 2005-02-15  -0.146616    -0.154083 -1.054609e-07         300.699837
# ...               ...          ...           ...                ...
# 2023-05-17   7.482347     7.571174  9.451536e-03        5186.998517
# 2023-08-16  -4.499693    -3.075079 -2.428485e-03        5303.949068
# 2023-11-15  10.837163     8.624810  4.059750e-04        6132.148695
# 2024-02-14   7.479580     8.165104  9.665364e-03        6805.360804
# 2024-05-15   1.111544    -1.241481  1.748389e-02        7043.931701
#
#             Volatility        MA30        MA60        MA90  Daily_Change_Pct
# Date
# 2003-02-19    0.022319   25.294000   26.372000   26.479722         -1.722750
# 2003-10-15    0.020040   28.693000   27.470333   27.061444          1.359830
# 2004-08-23    0.010606   27.819333   27.650833   27.112444          0.147055
# 2004-11-15    0.011422   28.448333   27.928833   27.899556         -8.608609
# 2005-02-15    0.006235   26.253667   26.612333   27.183000         -0.307574
# ...                ...         ...         ...         ...               ...
# 2023-05-17    0.020024  297.447998  281.466833  271.076444          0.724966
# 2023-08-16    0.014699  335.486997  333.955666  322.463332         -0.453611
# 2023-11-15    0.015193  341.567003  333.343503  333.334779         -0.162037
# 2024-02-14    0.013432  397.116665  385.510666  371.494001          0.780169
# 2024-05-15    0.015195  411.287332  413.357000  409.133777          1.565198
#
# [82 rows x 19 columns]
#
# Days with Stock Splits:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 1987-09-21   0.371528   0.397569   0.368056   0.371528   0.229082   85550400
# 1990-04-16   0.847222   0.857639   0.835069   0.843750   0.520251   39470400
# 1991-06-27   1.411458   1.421875   1.390625   1.416667   0.873508   56510400
# 1992-06-15   2.343750   2.437500   2.343750   2.367188   1.459594   54940800
# 1994-05-23   3.062500   3.187500   3.031250   3.160156   1.948533   74947200
# 1996-12-09   9.796875  10.234375   9.750000  10.218750   6.300822   94718400
# 1998-02-23  20.234375  20.421875  19.843750  20.406250  12.582369  120803600
# 1999-03-29  45.062500  46.312500  43.937500  46.187500  28.478926   79777000
# 2003-02-18  24.620001  24.990000  24.400000  24.959999  15.390184   57415500
#
#             Dividends  Stock Splits     SMA_50        RSI      MACD  \
# Date
# 1987-09-21        0.0           2.0   0.369089  41.666443  0.007072
# 1990-04-16        0.0           2.0   0.735503  72.280528  0.027314
# 1991-06-27        0.0           1.5   1.459931  42.022412 -0.023618
# 1992-06-15        0.0           1.5   2.422813  45.281761 -0.016240
# 1994-05-23        0.0           2.0   2.798281  69.336582  0.081865
# 1996-12-09        0.0           2.0   8.928907  73.567090  0.269273
# 1998-02-23        0.0           2.0  17.610781  74.000389  0.631700
# 1999-03-29        0.0           2.0  40.435313  70.062214  1.545545
# 2003-02-18        0.0           2.0  25.976900  51.363108 -0.676312
#
#             MACD_Signal  Daily_Return  Cumulative_Return  Volatility  \
# Date
# 1987-09-21     0.010481     -0.069566           2.821441    0.026948
# 1990-04-16     0.024711      0.006211           7.678595    0.017486
# 1991-06-27    -0.005156      0.012407          13.571472    0.022610
# 1992-06-15     0.003036      0.010001          23.348290    0.021725
# 1994-05-23     0.071337      0.034527          31.504545    0.018588
# 1996-12-09     0.264959      0.069501         104.107470    0.021537
# 1998-02-23     0.675118      0.052377         208.893408    0.017575
# 1999-03-29     1.101464      0.037193         474.072606    0.022012
# 2003-02-18    -0.822628      0.033540         255.732121    0.022135
#
#                  MA30       MA60       MA90  Daily_Change_Pct
# Date
# 1987-09-21   0.385692   0.364706   0.368683         -6.956570
# 1990-04-16   0.778270   0.718924   0.677595          0.621080
# 1991-06-27   1.487558   1.473235   1.457870          1.240681
# 1992-06-15   2.415451   2.447917   2.476765          1.000020
# 1994-05-23   2.883854   2.756641   2.696702          3.452661
# 1996-12-09   9.245703   8.851563   8.491233          6.950112
# 1998-02-23  18.447396  17.652604  17.327821          5.237712
# 1999-03-29  40.171354  39.750521  37.288368          3.719298
# 2003-02-18  25.389167  26.435000  26.451556          3.354035

# %% [markdown]
# #### Seasonality check
#  calculates and visualizes the average monthly closing price for the stock, providing insight into how the stock performs on average during each month of the year. It helps detect seasonal patterns in stock price movements.

# %%
print("\nMonthly Average Closing Prices:")
resample_and_plot_monthly_average(df, ticker)
# Out:
# Monthly Average Closing Prices:
# Month
# 1     57.738500
# 2     60.125862
# 3     58.756848
# 4     59.883933
# 5     60.626885
# 6     60.944021
# 7     63.751554
# 8     55.146837
# 9     54.261844
# 10    53.872440
# 11    57.967036
# 12    57.953100
# Name: Close, dtype: float64
