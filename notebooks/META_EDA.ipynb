# %% [markdown]
# ### Financial Stock Analysis
# This notebook performs analysis of META stock data, including technical indicators, financial metrics, and different kinds visualizations.

# %%
import sys
import os

# %%
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.financial_analyzer import *

# %%
# Load the data
df = load_stock_data('../data/yfinance_data/META_historical_data.csv')
# META ticker symbol 
ticker = 'META'

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2012-12-12  28.000000  28.139999  27.370001  27.580000  27.523441  46704200
# 2012-12-13  27.590000  28.750000  27.430000  28.240000  28.182087  81051600
# 2012-12-14  28.180000  28.330000  26.760000  26.809999  26.755020  91631600
# 2012-12-17  26.770000  27.000000  26.320000  26.750000  26.695143  57742500
# 2012-12-18  26.959999  27.910000  26.900000  27.709999  27.653173  60512900
#
#             Dividends  Stock Splits
# Date
# 2012-12-12        0.0           0.0
# 2012-12-13        0.0           0.0
# 2012-12-14        0.0           0.0
# 2012-12-17        0.0           0.0
# 2012-12-18        0.0           0.0

# %% [markdown]
# #### Basic Statistical Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2926 entries, 2012-12-12 to 2024-07-30
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          2926 non-null   float64
#  1   High          2926 non-null   float64
#  2   Low           2926 non-null   float64
#  3   Close         2926 non-null   float64
#  4   Adj Close     2926 non-null   float64
#  5   Volume        2926 non-null   int64
#  6   Dividends     2926 non-null   float64
#  7   Stock Splits  2926 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 205.7 KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2926.000000  2926.000000  2926.000000  2926.000000  2926.000000
# mean    179.557215   181.875331   177.317761   179.649453   179.305921
# std     108.864895   110.256219   107.511134   108.906971   108.755055
# min      22.990000    23.090000    22.670000    22.900000    22.853037
# 25%      97.767502    98.772499    95.889997    97.382498    97.182795
# 50%     166.870003   168.850006   164.210007   166.855003   166.512825
# 75%     231.450005   234.934998   228.687504   232.424999   231.948360
# max     542.349976   542.809998   528.359985   539.909973   539.909973
#
#              Volume    Dividends  Stock Splits
# count  2.926000e+03  2926.000000        2926.0
# mean   2.872083e+07     0.000342           0.0
# std    2.269811e+07     0.013070           0.0
# min    5.467500e+06     0.000000           0.0
# 25%    1.571308e+07     0.000000           0.0
# ...

# %%
df.shape
# Out:
# (2926, 8)

# %% [markdown]
# ### Technical Indicators
# Technical indicators are statistical calculations that analyze historical price data to identify potential trading signals.
# The function calculate technical indicators like: 50-day SImple Moving Average(SMA), 14-day Relative Strength Index (RSI) and Moving Average Convergence Divergence (MACD) with a fast period of 12, a slow period of 26, and a signal period of 9

# %%
#  Calculate technical indicators
df = technical_indicators(df)

# plot plot_technical_indicators
plot_technical_indicators(df, ticker)

# %% [markdown]
# ### Financial Metrics
# calculate and display some key financial metrics:average daily return, total cumulative return, average volatility, total dividends paid, number of stock splits. They give us insight into the stock's performance over time.

# %%
# Calculate financial metrics
df = financial_metrics(df)

# plot for the financial analyzer 
plot_financial_metrics(df, ticker)

# %% [markdown]
# #### stock price movements
# visualizes adjusted stock price data and a 50-day Simple Moving Average (SMA)

# %%
 #stock's price movements
plot_stock_data(df, ticker)

# %% [markdown]
# #### volume vs dividends
#  relationship between stock volume and dividend payments over time to see insights for market dynamics,
#  investor behavior, and potential trading opportunities.

# %%
plot_volume_and_dividends(df, ticker)

# %% [markdown]
# ### Other  Analysis

# %% [markdown]
# #####  Closing price over time to see long-term trends, whether the stock is generally increasing or decreasing

# %%
# plot closing price over the year 
plot_time_series_closing_price(df, ticker)

# %% [markdown]
# #####  trading volume of a stock over time.
#  helps identify periods of high or low market activity, providing insights into liquidity, investor interest, and market sentiment for the stock

# %%
plot_time_series_volume(df, ticker)

# %% [markdown]
# #####  Moving Averages
# plots for three different moving averages (30-day, 60-day, and 90-day) for a stock's closing prices to identify trends and momentum over specific time periods and it also helps detect potential reversals or confirmations of market trends.

# %%
calculate_and_plot_moving_averages(df, ticker)

# %% [markdown]
# #####   daily price change percentage for the stock

# %%
calculate_and_plot_daily_change(df, ticker)

# %% [markdown]
# #### daily price change percentage and trading volume
#  To identify whether significant price movements are associated with higher or lower trading volumes,

# %%
plot_volume_vs_price_change(df, ticker)

# %%
# Analyze the results
print("Basic Statistics:")
print(df.describe())
# Out:
# Basic Statistics:
#               Open         High          Low        Close    Adj Close  \
# count  2926.000000  2926.000000  2926.000000  2926.000000  2926.000000
# mean    179.557215   181.875331   177.317761   179.649453   179.305921
# std     108.864895   110.256219   107.511134   108.906971   108.755055
# min      22.990000    23.090000    22.670000    22.900000    22.853037
# 25%      97.767502    98.772499    95.889997    97.382498    97.182795
# 50%     166.870003   168.850006   164.210007   166.855003   166.512825
# 75%     231.450005   234.934998   228.687504   232.424999   231.948360
# max     542.349976   542.809998   528.359985   539.909973   539.909973
#
#              Volume    Dividends  Stock Splits       SMA_50          RSI  \
# count  2.926000e+03  2926.000000        2926.0  2877.000000  2912.000000
# mean   2.872083e+07     0.000342           0.0   178.268660    54.377650
# std    2.269811e+07     0.013070           0.0   104.118881    11.805690
# ...

# %% [markdown]
# #### correlation matrix to see how different variables relate to each other.
# Open, Low, Close, and Adjusted_Close prices are highly positively correlated with each other, simce because they are all measures of stock prices within the same trading day.

# %%
print("\nCorrelation Matrix:")
print(df[[ 'Open','Close','High','Low', 'Adj Close', 'SMA_50', 'RSI', 'MACD', 'Daily_Return', 'Cumulative_Return', 'Volatility', 'Volume', 'Dividends']].corr())
# Out:
# Correlation Matrix:
#                        Open     Close      High       Low  Adj Close  \
# Open               1.000000  0.999491  0.999774  0.999747   0.999492
# Close              0.999491  1.000000  0.999768  0.999779   0.999999
# High               0.999774  0.999768  1.000000  0.999713   0.999768
# Low                0.999747  0.999779  0.999713  1.000000   0.999778
# Adj Close          0.999492  0.999999  0.999768  0.999778   1.000000
# SMA_50             0.984410  0.984072  0.984725  0.983703   0.984078
# RSI                0.064783  0.071992  0.065371  0.071966   0.071943
# MACD               0.293849  0.294705  0.291845  0.297179   0.294685
# Daily_Return      -0.008980  0.010247 -0.000101  0.000848   0.010227
# Cumulative_Return  0.999492  0.999999  0.999768  0.999778   1.000000
# Volatility        -0.018182 -0.017787 -0.013077 -0.022047  -0.017770
# Volume            -0.391211 -0.391652 -0.387068 -0.395943  -0.391539
# ...

# %%
# Additional analysis
print("\nAverage Daily Return:", df['Daily_Return'].mean())
print("Total Cumulative Return:", df['Cumulative_Return'].iloc[-1])
print("Average Volatility:", df['Volatility'].mean())
print("Total Dividends Paid:", df['Dividends'].sum())
print("Number of Stock Splits:", df['Stock Splits'].sum())
# Out:
# Average Daily Return: 0.0012603198603272554
# Total Cumulative Return: 15.828927645543704
# Average Volatility: 0.0214652537474844
# Total Dividends Paid: 1.0
# Number of Stock Splits: 0.0

# %%
 #Analyze the impact of dividends and stock splits on the stock's performance 
print("\nDays with Dividends:")
print(df[df['Dividends'] > 0])

print("\nDays with Stock Splits:")
print(df[df['Stock Splits'] > 0])
# Out:
# Days with Dividends:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-02-21  466.500000  469.000000  461.790009  468.029999  467.565765
# 2024-06-14  502.649994  507.149994  500.750000  504.160004  504.160004
#
#               Volume  Dividends  Stock Splits      SMA_50        RSI  \
# Date
# 2024-02-21  12977100        0.5           0.0  390.299400  66.398184
# 2024-06-14  10243300        0.5           0.0  481.371002  63.442997
#
#                  MACD  MACD_Signal  Daily_Return  Cumulative_Return  \
# Date
# 2024-02-21  26.211851    26.766425     -0.006833          15.987911
# 2024-06-14   8.623455     5.394191      0.001112          17.317477
#
#             Volatility     MA30        MA60        MA90  Daily_Change_Pct
# Date
# 2024-02-21    0.048529  419.824  379.890167  359.531778         -0.788554
# 2024-06-14    0.013789  479.116  484.510335  484.993000          0.011902
#
# Days with Stock Splits:
# Empty DataFrame
# ...

# %% [markdown]
# #### Seasonality check
#  calculates and visualizes the average monthly closing price for the stock, providing insight into how the stock performs on average during each month of the year. It helps detect seasonal patterns in stock price movements.

# %%
print("\nMonthly Average Closing Prices:")
resample_and_plot_monthly_average(df, ticker)
# Out:
# Monthly Average Closing Prices:
# Month
# 1     169.198361
# 2     176.413565
# 3     175.076130
# 4     181.331205
# 5     187.496863
# 6     192.733360
# 7     200.757786
# 8     178.820820
# 9     176.974622
# 10    171.791235
# 11    175.166444
# 12    167.927008
# Name: Close, dtype: float64
